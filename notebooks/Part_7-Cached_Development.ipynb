# %% [markdown]
# ## Setup and Dependencies

# %%
# --- Extension Setup ---
# %load_ext line_profiler
# %load_ext autoreload

# %autoreload 2 -p

# --- Autoreload Target ---
# %aimport afml

# --- AFML Initialization ---
import afml

# --- Module Imports ---
import sys
sys.path.append("..")  # Adjust if your afml repo is nested differently
# Out:
# 2025-12-01 13:43:57.824 | DEBUG    | afml.cache:<module>:669 - Enhanced cache features available:
# 2025-12-01 13:43:57.826 | DEBUG    | afml.cache:<module>:670 -   - Robust cache keys for NumPy/Pandas
# 2025-12-01 13:43:57.827 | DEBUG    | afml.cache:<module>:671 -   - MLflow integration: ✓
# 2025-12-01 13:43:57.832 | DEBUG    | afml.cache:<module>:672 -   - Backtest caching: ✓
# 2025-12-01 13:43:57.838 | DEBUG    | afml.cache:<module>:673 -   - Cache monitoring: ✓
# 2025-12-01 13:43:57.841 | DEBUG    | afml.cache:<module>:674 -   - Cache size analysis: ✓
# 2025-12-01 13:43:57.844 | DEBUG    | afml.cache:<module>:675 -   - Robust cache keys for NumPy/Pandas
# 2025-12-01 13:43:57.845 | DEBUG    | afml.cache:<module>:676 -   - MLflow integration: ✓
# 2025-12-01 13:43:57.847 | DEBUG    | afml.cache:<module>:677 -   - Backtest caching: ✓
# 2025-12-01 13:43:57.849 | DEBUG    | afml.cache:<module>:678 -   - Cache monitoring: ✓
# 2025-12-01 13:43:57.850 | DEBUG    | afml.cache:<module>:679 -   - Cache size analysis: ✓
# 2025-12-01 13:43:59.166 | DEBUG    | afml.cache:_configure_numba:59 - Numba cache configured: C:\Users\JoeN\AppData\Local\afml\afml\Cache\numba_cache
# 2025-12-01 13:43:59.167 | INFO     | afml.cache:initialize_cache_system:245 - AFML cache system initialized:
# 2025-12-01 13:43:59.175 | INFO     | afml.cache:initialize_cache_system:246 -   Joblib cache: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 13:43:59.181 | INFO     | afml.cache:initialize_cache_system:247 -   Numba cache: C:\Users\JoeN\AppData\Local\afml\afml\Cache\numba_cache
# 2025-12-01 13:43:59.183 | INFO     | afml.cache:initialize_cache_system:253 -   Loaded stats: 6 functions, 80.4% hit rate
# 2025-12-01 13:44:04.230 | DEBUG    | afml.cache.selective_cleaner:_load_tracking_data:36 - Loaded tracking data for 20 functions
# 2025-12-01 13:44:05.540 | DEBUG    | afml:<module>:137 - Imported lightweight modules directly
# 2025-12-01 13:44:05.542 | INFO     | afml:<module>:399 - AFML v1.0.0 ready - 10 heavy modules available for lazy loading
# 2025-12-01 13:44:05.545 | DEBUG    | afml:<module>:402 - Cache status: Hit rate: 80.4% | Tracked functions: 6 | Heavy modules loaded: 0
# 2025-12-01 13:44:05.549 | DEBUG    | afml:<module>:406 - ✓ Cache monitoring available
# 2025-12-01 13:44:05.556 | DEBUG    | afml:<module>:408 - ✓ MLflow integration available
# 2025-12-01 13:44:05.561 | DEBUG    | afml:<module>:410 - ✓ Backtest caching available

# %%
import re
import time
import warnings
import winsound
from pathlib import Path
from pprint import pprint

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.base import clone
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    log_loss,
    precision_score,
    recall_score,
)
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm

from afml.cross_validation import (
    PurgedKFold,
    PurgedSplit,
    analyze_cross_val_scores,
    analyze_cross_val_scores_calibrated,
    clf_hyper_fit,
    probability_weighted_accuracy,
)
from afml.data_structures.bars import *
from afml.ensemble import (
    SequentiallyBootstrappedBaggingClassifier,
    compute_custom_oob_metrics,
    estimate_ensemble_size,
)
from afml.labeling.triple_barrier import (
    add_vertical_barrier,
    get_event_weights,
    triple_barrier_labels,
)
from afml.sample_weights.optimized_attribution import (
    get_weights_by_time_decay_optimized,
)
from afml.strategies import (
    BollingerStrategy,
    ForexFeatureEngine,
    MACrossoverStrategy,
    create_bollinger_features,
    get_entries,
)
from afml.util import get_daily_vol, value_counts_data
from afml.util.misc import expand_params, value_counts_data
from tools.module_reloader import reload_with_dependencies

warnings.filterwarnings("ignore")
# plt.style.use("seaborn-v0_8-whitegrid")
plt.style.use("dark_background")

# %%
# from afml.cache import clear_data_access_log, clear_afml_cache


# clear_afml_cache()
# clear_data_access_log()

# %% [markdown]
# ## 0. Data Collection and Cleaning

# %%
# Your Account Name for  MT5 fetched from a .env file of your configuration
account_name = "FUNDEDNEXT_STLR2_6K"

# %%
from afml.cache.cv_cache import cv_cacheable


@cv_cacheable
def train_rf(classifier, X, y, sample_weight=None):
    time0 = time.time()
    clf = clone(classifier).set_params(oob_score=True).fit(X, y, sample_weight)
    duration = str(pd.Timedelta(time.time() - time0, unit="s").round("s")).replace("0 days", "")
    print(f"{clf.__class__.__name__} trained in {duration}.")
    return clf

# %% [markdown]
# ## 1. Bollinger Band Strategy

# %%
symbol = "EURUSD"
start_date = "2022-01-01"
end_date = "2023-12-31"
account_name = "FUNDEDNEXT_STLR2_6K"

# %%
bb_period, bb_std = 20, 1.5 # Bollinger Band parameters
bb_strategy = BollingerStrategy(window=bb_period, num_std=bb_std)
bb_lookback = 100
bb_pt_barrier, bb_sl_barrier, bb_time_horizon = (1, 2, dict(days=1))
bb_vol_multiplier = 1

# %% [markdown]
# ### Time-Bars

# %%
from scipy.stats import uniform


def uniform_range(low, high):
    return uniform(loc=low, scale=high - low)

# Example: between 0.5 and 0.9
dist = uniform_range(0.5, 0.9)

# %%
from os import cpu_count
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures
from scipy.stats import randint, uniform
from scipy.stats.distributions import rv_continuous
from sklearn import preprocessing
from sklearn.pipeline import Pipeline

from afml.cross_validation.hyperfit import MyPipeline

n_jobs = cpu_count() - 1
pipe = MyPipeline([
        ("drop_constant", DropConstantFeatures(tol=0.998)),  # remove constant features
        ("drop_duplicates", DropDuplicateFeatures()),        # remove duplicate features
        ("clf", RandomForestClassifier(n_jobs=n_jobs, random_state=42, class_weight="balanced_subsample")),
        ])
param_distributions = {
    "clf__n_estimators": randint(100, 500),                 # sample integers between 100 and 500
    "clf__max_depth": randint(3, 20),                       # sample integers between 3 and 20
    "clf__max_features": uniform_range(0.1, 1),                 # sample floats between 0.1 and 1.0
    "clf__max_samples": uniform_range(0.5, 1),                  # sample floats between 0.1 and 1.0
    "clf__min_weight_fraction_leaf": uniform_range(0.01, 0.05),        # sample floats between 0.01 and 0.05
}

model_params = dict(
    pipe_clf=pipe,
    param_grid=param_distributions,
    cv_splits=5,
    bagging_n_estimators=0,
    bagging_max_samples=1,
    bagging_max_features=1,
    rnd_search_iter=1,
    n_jobs=-1,
    pct_embargo=0.01,
    random_state=42,
    verbose=False,
)
sample_weight_config = dict(
    attribution=["uniqueness"],
    decay_factor=[0.0, 0.25, 0.5, 0.75, 1.0],
    linear=[True],
)

feature_params = dict(
    bb_period=np.arange(15,30,5),
    bb_std=np.arange(1.5, 2.1, 0.25)

)

data_config = dict(
    account_name=[account_name],
    bar_type=["time", "tick"],
    bar_size=["M5"],
    price=["mid_price"]
)
label_params = dict(
    target_lookback=np.arange(20, 101, 20),
    profit_target=np.arange(0, 2.5, 0.5),
    stop_loss=np.arange(0.5, 2.5, 0.5),
    max_holding_period=[dict(days=1)],
    min_ret=[0],
    vertical_barrier_zero=[True],
)

# %%
np.product([len(expand_params(x)) for x in [sample_weight_config, feature_params, label_params, data_config]])
# Out:
# 9000

# %%
all_cv_metrics = {}

# %%
all_cv_metrics
# Out:
# {1: {'key': [{'account_name': 'FUNDEDNEXT_STLR2_6K',
#     'bar_type': 'time',
#     'bar_size': 'M5',
#     'price': 'mid_price'},
#    {'bb_period': 15, 'bb_std': 1.5},
#    {'target_lookback': 20,
#     'profit_target': 0.0,
#     'stop_loss': 0.5,
#     'max_holding_period': {'days': 1},
#     'min_ret': 0,
#     'vertical_barrier_zero': True,
#     'strategy': <afml.strategies.signals.BollingerStrategy at 0x2344079bd30>},
#    {'pipe_clf': MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                       ('drop_duplicates', DropDuplicateFeatures()),
#                       ('clf',
#                        RandomForestClassifier(class_weight='balanced_subsample',
#                                               n_jobs=3, random_state=42))]),
#     'param_grid': {'clf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x2343090c790>,
#      'clf__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x2343090cbb0>,
#      'clf__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090c1f0>,
#      'clf__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090c100>,
#      'clf__min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090cc10>},
#     'cv_splits': 5,
#     'bagging_n_estimators': 0,
#     'bagging_max_samples': 1,
#     'bagging_max_features': 1,
#     'rnd_search_iter': 1,
#     'n_jobs': -1,
#     'pct_embargo': 0.01,
#     'random_state': 42,
#     'verbose': False},
#    {'attribution': 'uniqueness', 'decay_factor': 0.0, 'linear': True}],
#   'result': (MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                      ('drop_duplicates', DropDuplicateFeatures()),
#                      ('clf',
#                       RandomForestClassifier(class_weight='balanced_subsample',
#                                              max_depth=9,
#                                              max_features=0.8168886881742096,
#                                              max_samples=0.5917173949330818,
#                                              min_weight_fraction_leaf=0.04118764001091077,
#                                              n_estimators=120, n_jobs=1,
#                                              random_state=42))]),
#    ['spread',
#     'vol',
#     'h1_vol',
#     'h4_vol',
#     'd1_vol',
#     'ret',
#     'ret_5',
#     'ret_10',
#     'ret_1_lag_1',
#     'ret_5_lag_1',
#     'ret_10_lag_1',
#     'ret_1_lag_2',
#     'ret_5_lag_2',
#     'ret_10_lag_2',
#     'ret_1_lag_3',
#     'ret_5_lag_3',
#     'ret_10_lag_3',
#     'ret_skew',
#     'ret_kurt',
#     'autocorr',
#     'autocorr_1',
#     'autocorr_2',
#     'autocorr_3',
#     'autocorr_4',
#     'autocorr_5',
#     'bbb_15_1.5',
#     'bbp_15_1.5',
#     'truerange_1',
#     'atrr_14',
#     'rsi_14',
#     'stochrsik_14_14_3_3',
#     'stochrsid_14_14_3_3',
#     'adx_14',
#     'dmp_14',
#     'dmn_14',
#     'dm_net',
#     'macd_12_26_9',
#     'macdh_12_26_9',
#     'sma_diff_10_20',
#     'sma_diff_10_50',
#     'sma_diff_10_100',
#     'sma_diff_10_200',
#     'sma_diff_20_50',
#     'sma_diff_20_100',
#     'sma_diff_20_200',
#     'sma_diff_50_100',
#     'sma_diff_50_200',
#     'sma_diff_100_200',
#     'sma_cross_10_20',
#     'sma_cross_10_50',
#     'sma_cross_10_100',
#     'sma_cross_10_200',
#     'sma_cross_20_50',
#     'sma_cross_20_100',
#     'sma_cross_20_200',
#     'sma_cross_50_100',
#     'sma_cross_50_200',
#     'sma_cross_100_200',
#     'side'],
#    {'cv_results': {'best_params': {'clf__max_depth': 9,
#       'clf__max_features': 0.8168886881742096,
#       'clf__max_samples': 0.5917173949330818,
#       'clf__min_weight_fraction_leaf': 0.04118764001091077,
#       'clf__n_estimators': 120},
#      'best_score': 0.21187500424561306,
#      'cv_results':    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
#      0      36.871146      4.449743         0.082913        0.020654
#
#         param_clf__max_depth  param_clf__max_features  param_clf__max_samples  \
#      0                     9                 0.816889                0.591717
#
#         param_clf__min_weight_fraction_leaf  param_clf__n_estimators  \
#      0                             0.041188                      120
#
#                                                    params  split0_test_score  \
#      0  {'clf__max_depth': 9, 'clf__max_features': 0.8...            0.23199
#
#         split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
#      0           0.226067           0.251761            0.18442           0.165138
#
#         mean_test_score  std_test_score  rank_test_score
#      0         0.211875        0.032047                1  ,
#      'scoring': 'f1'},
#     'feature_importance':                 feature  importance
#     4                d1_vol    0.259825
#     1                   vol    0.044798
#     0                spread    0.042814
#     14          ret_1_lag_3    0.033937
#     27          truerange_1    0.029784
#     25           bbb_15_1.5    0.028060
#     2                h1_vol    0.027820
#     17             ret_skew    0.019933
#     9           ret_5_lag_1    0.019810
#     11          ret_1_lag_2    0.019607
#     18             ret_kurt    0.019445
#     46      sma_diff_50_200    0.019020
#     16         ret_10_lag_3    0.018898
#     13         ret_10_lag_2    0.018227
#     37        macdh_12_26_9    0.016965
#     30  stochrsik_14_14_3_3    0.016789
#     12          ret_5_lag_2    0.016287
#     28              atrr_14    0.016283
#     3                h4_vol    0.016039
#     34               dmn_14    0.015752
#     45      sma_diff_50_100    0.015056
#     32               adx_14    0.014640
#     31  stochrsid_14_14_3_3    0.014630
#     8           ret_1_lag_1    0.014589
#     44      sma_diff_20_200    0.013738
#     24           autocorr_5    0.013718
#     19             autocorr    0.013449
#     5                   ret    0.013393
#     7                ret_10    0.013286
#     43      sma_diff_20_100    0.012726
#     35               dm_net    0.012459
#     38       sma_diff_10_20    0.012452
#     47     sma_diff_100_200    0.011747
#     41      sma_diff_10_200    0.010271
#     21           autocorr_2    0.010070
#     10         ret_10_lag_1    0.009849
#     23           autocorr_4    0.009792
#     6                 ret_5    0.009709
#     15          ret_5_lag_3    0.009526
#     22           autocorr_3    0.009353
#     33               dmp_14    0.009181
#     42       sma_diff_20_50    0.008816
#     20           autocorr_1    0.008022
#     26           bbp_15_1.5    0.007037
#     40      sma_diff_10_100    0.006163
#     36         macd_12_26_9    0.005546
#     29               rsi_14    0.005373
#     39       sma_diff_10_50    0.004573
#     57    sma_cross_100_200    0.000290
#     48      sma_cross_10_20    0.000227
#     49      sma_cross_10_50    0.000226
#     50     sma_cross_10_100    0.000000
#     51     sma_cross_10_200    0.000000
#     52      sma_cross_20_50    0.000000
#     53     sma_cross_20_100    0.000000
#     54     sma_cross_20_200    0.000000
#     55     sma_cross_50_100    0.000000
#     56     sma_cross_50_200    0.000000
#     58                 side    0.000000,
#     'training_samples': 147860,
#     'feature_count': 59})},
#  2: {'key': [{'account_name': 'FUNDEDNEXT_STLR2_6K',
#     'bar_type': 'time',
#     'bar_size': 'M5',
#     'price': 'mid_price'},
#    {'bb_period': 15, 'bb_std': 1.5},
#    {'target_lookback': 20,
#     'profit_target': 0.0,
#     'stop_loss': 1.0,
#     'max_holding_period': {'days': 1},
#     'min_ret': 0,
#     'vertical_barrier_zero': True,
#     'strategy': <afml.strategies.signals.BollingerStrategy at 0x234380fc3a0>},
#    {'pipe_clf': MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                       ('drop_duplicates', DropDuplicateFeatures()),
#                       ('clf',
#                        RandomForestClassifier(class_weight='balanced_subsample',
#                                               n_jobs=3, random_state=42))]),
#     'param_grid': {'clf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x2343090c790>,
#      'clf__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x2343090cbb0>,
#      'clf__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090c1f0>,
#      'clf__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090c100>,
#      'clf__min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090cc10>},
#     'cv_splits': 5,
#     'bagging_n_estimators': 0,
#     'bagging_max_samples': 1,
#     'bagging_max_features': 1,
#     'rnd_search_iter': 1,
#     'n_jobs': -1,
#     'pct_embargo': 0.01,
#     'random_state': 42,
#     'verbose': False},
#    {'attribution': 'uniqueness', 'decay_factor': 0.0, 'linear': True}],
#   'result': (MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                      ('drop_duplicates', DropDuplicateFeatures()),
#                      ('clf',
#                       RandomForestClassifier(class_weight='balanced_subsample',
#                                              max_depth=9,
#                                              max_features=0.8168886881742096,
#                                              max_samples=0.5917173949330818,
#                                              min_weight_fraction_leaf=0.04118764001091077,
#                                              n_estimators=120, n_jobs=1,
#                                              random_state=42))]),
#    ['spread',
#     'vol',
#     'h1_vol',
#     'h4_vol',
#     'd1_vol',
#     'ret',
#     'ret_5',
#     'ret_10',
#     'ret_1_lag_1',
#     'ret_5_lag_1',
#     'ret_10_lag_1',
#     'ret_1_lag_2',
#     'ret_5_lag_2',
#     'ret_10_lag_2',
#     'ret_1_lag_3',
#     'ret_5_lag_3',
#     'ret_10_lag_3',
#     'ret_skew',
#     'ret_kurt',
#     'autocorr',
#     'autocorr_1',
#     'autocorr_2',
#     'autocorr_3',
#     'autocorr_4',
#     'autocorr_5',
#     'bbb_15_1.5',
#     'bbp_15_1.5',
#     'truerange_1',
#     'atrr_14',
#     'rsi_14',
#     'stochrsik_14_14_3_3',
#     'stochrsid_14_14_3_3',
#     'adx_14',
#     'dmp_14',
#     'dmn_14',
#     'dm_net',
#     'macd_12_26_9',
#     'macdh_12_26_9',
#     'sma_diff_10_20',
#     'sma_diff_10_50',
#     'sma_diff_10_100',
#     'sma_diff_10_200',
#     'sma_diff_20_50',
#     'sma_diff_20_100',
#     'sma_diff_20_200',
#     'sma_diff_50_100',
#     'sma_diff_50_200',
#     'sma_diff_100_200',
#     'sma_cross_10_20',
#     'sma_cross_10_50',
#     'sma_cross_10_100',
#     'sma_cross_10_200',
#     'sma_cross_20_50',
#     'sma_cross_20_100',
#     'sma_cross_20_200',
#     'sma_cross_50_100',
#     'sma_cross_50_200',
#     'sma_cross_100_200',
#     'side'],
#    {'cv_results': {'best_params': {'clf__max_depth': 9,
#       'clf__max_features': 0.8168886881742096,
#       'clf__max_samples': 0.5917173949330818,
#       'clf__min_weight_fraction_leaf': 0.04118764001091077,
#       'clf__n_estimators': 120},
#      'best_score': 0.33906882766844737,
#      'cv_results':    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
#      0       30.19696      0.443946         0.082576        0.025478
#
#         param_clf__max_depth  param_clf__max_features  param_clf__max_samples  \
#      0                     9                 0.816889                0.591717
#
#         param_clf__min_weight_fraction_leaf  param_clf__n_estimators  \
#      0                             0.041188                      120
#
#                                                    params  split0_test_score  \
#      0  {'clf__max_depth': 9, 'clf__max_features': 0.8...           0.350313
#
#         split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
#      0           0.386431           0.377922           0.288708           0.291971
#
#         mean_test_score  std_test_score  rank_test_score
#      0         0.339069        0.041554                1  ,
#      'scoring': 'f1'},
#     'feature_importance':                 feature  importance
#     4                d1_vol    0.397741
#     1                   vol    0.040409
#     2                h1_vol    0.028852
#     0                spread    0.026054
#     28              atrr_14    0.025496
#     11          ret_1_lag_2    0.024160
#     25           bbb_15_1.5    0.023745
#     16         ret_10_lag_3    0.022784
#     14          ret_1_lag_3    0.020761
#     3                h4_vol    0.019431
#     35               dm_net    0.016069
#     17             ret_skew    0.015955
#     38       sma_diff_10_20    0.015332
#     34               dmn_14    0.014994
#     31  stochrsid_14_14_3_3    0.013768
#     9           ret_5_lag_1    0.013765
#     12          ret_5_lag_2    0.013701
#     15          ret_5_lag_3    0.012944
#     37        macdh_12_26_9    0.012874
#     41      sma_diff_10_200    0.011765
#     18             ret_kurt    0.011480
#     13         ret_10_lag_2    0.011150
#     23           autocorr_4    0.011092
#     27          truerange_1    0.011080
#     7                ret_10    0.010936
#     33               dmp_14    0.010833
#     47     sma_diff_100_200    0.010828
#     32               adx_14    0.010668
#     46      sma_diff_50_200    0.009815
#     19             autocorr    0.009542
#     5                   ret    0.009490
#     6                 ret_5    0.009258
#     42       sma_diff_20_50    0.009180
#     45      sma_diff_50_100    0.008675
#     8           ret_1_lag_1    0.008409
#     24           autocorr_5    0.008042
#     30  stochrsik_14_14_3_3    0.006843
#     26           bbp_15_1.5    0.006649
#     10         ret_10_lag_1    0.006600
#     44      sma_diff_20_200    0.006430
#     20           autocorr_1    0.006416
#     21           autocorr_2    0.006049
#     40      sma_diff_10_100    0.005855
#     36         macd_12_26_9    0.005844
#     22           autocorr_3    0.005515
#     29               rsi_14    0.005346
#     39       sma_diff_10_50    0.003821
#     43      sma_diff_20_100    0.003373
#     55     sma_cross_50_100    0.000181
#     48      sma_cross_10_20    0.000000
#     49      sma_cross_10_50    0.000000
#     50     sma_cross_10_100    0.000000
#     51     sma_cross_10_200    0.000000
#     52      sma_cross_20_50    0.000000
#     53     sma_cross_20_100    0.000000
#     54     sma_cross_20_200    0.000000
#     56     sma_cross_50_200    0.000000
#     57    sma_cross_100_200    0.000000
#     58                 side    0.000000,
#     'training_samples': 147860,
#     'feature_count': 59})},
#  3: {'key': [{'account_name': 'FUNDEDNEXT_STLR2_6K',
#     'bar_type': 'time',
#     'bar_size': 'M5',
#     'price': 'mid_price'},
#    {'bb_period': 15, 'bb_std': 1.5},
#    {'target_lookback': 20,
#     'profit_target': 0.0,
#     'stop_loss': 1.5,
#     'max_holding_period': {'days': 1},
#     'min_ret': 0,
#     'vertical_barrier_zero': True,
#     'strategy': <afml.strategies.signals.BollingerStrategy at 0x234409c7670>},
#    {'pipe_clf': MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                       ('drop_duplicates', DropDuplicateFeatures()),
#                       ('clf',
#                        RandomForestClassifier(class_weight='balanced_subsample',
#                                               n_jobs=3, random_state=42))]),
#     'param_grid': {'clf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x2343090c790>,
#      'clf__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen at 0x2343090cbb0>,
#      'clf__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090c1f0>,
#      'clf__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090c100>,
#      'clf__min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen at 0x2343090cc10>},
#     'cv_splits': 5,
#     'bagging_n_estimators': 0,
#     'bagging_max_samples': 1,
#     'bagging_max_features': 1,
#     'rnd_search_iter': 1,
#     'n_jobs': -1,
#     'pct_embargo': 0.01,
#     'random_state': 42,
#     'verbose': False},
#    {'attribution': 'uniqueness', 'decay_factor': 0.0, 'linear': True}]}}

# %%
from afml.filters.filters import cusum_filter
from afml.production.model_development import (
    develop_production_model,
    load_and_prepare_training_data,
)


i = 0

for data_cfg in expand_params(data_config):
    for feature_cfg in expand_params(feature_params):
        feat_params = {"func": create_bollinger_features, "params": feature_cfg}
        for label_cfg in expand_params(label_params):
            label_cfg["strategy"] = BollingerStrategy(window=feature_cfg["bb_period"], num_std=feature_cfg["bb_std"])
            for sample_weight_cfg in expand_params(sample_weight_config):
                i += 1
                print(f"{i}. \n  {data_cfg} \n  {feature_cfg} \n  {label_cfg} \n  {model_params}\n")
                all_cv_metrics.setdefault(i, {})
                all_cv_metrics[i]["key"] = [data_cfg, feature_cfg, label_cfg, model_params, sample_weight_cfg]
                best_model, model_features, metrics = develop_production_model(
                    symbol, start_date, end_date, data_cfg, feat_params, label_cfg, model_params, sample_weight_cfg
                )
                all_cv_metrics[i]["result"] = best_model, model_features, metrics
                break
# Out:
# 2025-12-01 14:21:40.010 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.load_and_prepare_training_data
# 2025-12-01 14:21:40.157 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.create_feature_engineering_pipeline
# 1.
#   {'account_name': 'FUNDEDNEXT_STLR2_6K', 'bar_type': 'time', 'bar_size': 'M5', 'price': 'mid_price'}
#   {'bb_period': 15, 'bb_std': 1.5}
#   {'target_lookback': 20, 'profit_target': 0.0, 'stop_loss': 0.5, 'max_holding_period': {'days': 1}, 'min_ret': 0, 'vertical_barrier_zero': True, 'strategy': <afml.strategies.signals.BollingerStrategy object at 0x000002344079BD30>}
#   {'pipe_clf': MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                   ('drop_duplicates', DropDuplicateFeatures()),
#                   ('clf',
#                    RandomForestClassifier(class_weight='balanced_subsample',
#                                           n_jobs=3, random_state=42))]), 'param_grid': {'clf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002343090C790>, 'clf__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002343090CBB0>, 'clf__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090C1F0>, 'clf__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090C100>, 'clf__min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090CC10>}, 'cv_splits': 5, 'bagging_n_estimators': 0, 'bagging_max_samples': 1, 'bagging_max_features': 1, 'rnd_search_iter': 1, 'n_jobs': -1, 'pct_embargo': 0.01, 'random_state': 42, 'verbose': False}
#
#
# ======================================================================
# PRODUCTION MODEL DEVELOPMENT PIPELINE
# ======================================================================
#
# [Step 1/6] Loading training data...
# ✓ Loaded 147,860 samples from 2022-01-01 to 2023-12-31
#
# [Step 2/6] Computing features...
# 2025-12-01 14:21:40.812 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.generate_events_triple_barrier
# 2025-12-01 14:21:40.916 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.compute_sample_weights_time_decay
# ✓ Generated 59 features
#
# [Step 3/6] Generating events...
# ✓ Generated events:
#      count  proportion
# bin
# 0    8,616    0.866888
# 1    1,323    0.133112
#
# [Step 4/6] Computing sample weights...
# ✓ Computed time-decay weights
#
# [Step 5/6] Training model with cross-validation...
# 2025-12-01 14:21:41.474 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.train_model_with_cv
# ✓ Best CV score: 0.2119
# ✓ Best params: {'clf__max_depth': 9, 'clf__max_features': 0.8168886881742096, 'clf__max_samples': 0.5917173949330818, 'clf__min_weight_fraction_leaf': 0.04118764001091077, 'clf__n_estimators': 120}
#
# [Step 6/6] Analyzing feature importance...
#
# Top 10 Features:
#     feature  importance
#      d1_vol    0.259825
#         vol    0.044798
#      spread    0.042814
# ret_1_lag_3    0.033937
# truerange_1    0.029784
#  bbb_15_1.5    0.028060
#      h1_vol    0.027820
#    ret_skew    0.019933
# ret_5_lag_1    0.019810
# ret_1_lag_2    0.019607
# 2.
#   {'account_name': 'FUNDEDNEXT_STLR2_6K', 'bar_type': 'time', 'bar_size': 'M5', 'price': 'mid_price'}
#   {'bb_period': 15, 'bb_std': 1.5}
#   {'target_lookback': 20, 'profit_target': 0.0, 'stop_loss': 1.0, 'max_holding_period': {'days': 1}, 'min_ret': 0, 'vertical_barrier_zero': True, 'strategy': <afml.strategies.signals.BollingerStrategy object at 0x00000234380FC3A0>}
#   {'pipe_clf': MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                   ('drop_duplicates', DropDuplicateFeatures()),
#                   ('clf',
#                    RandomForestClassifier(class_weight='balanced_subsample',
#                                           n_jobs=3, random_state=42))]), 'param_grid': {'clf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002343090C790>, 'clf__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002343090CBB0>, 'clf__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090C1F0>, 'clf__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090C100>, 'clf__min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090CC10>}, 'cv_splits': 5, 'bagging_n_estimators': 0, 'bagging_max_samples': 1, 'bagging_max_features': 1, 'rnd_search_iter': 1, 'n_jobs': -1, 'pct_embargo': 0.01, 'random_state': 42, 'verbose': False}
#
#
# ======================================================================
# PRODUCTION MODEL DEVELOPMENT PIPELINE
# ======================================================================
#
# [Step 1/6] Loading training data...
# 2025-12-01 14:21:42.996 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.load_and_prepare_training_data
# 2025-12-01 14:21:43.177 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.create_feature_engineering_pipeline
# ✓ Loaded 147,860 samples from 2022-01-01 to 2023-12-31
#
# [Step 2/6] Computing features...
# 2025-12-01 14:21:43.504 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.generate_events_triple_barrier
# ✓ Generated 59 features
#
# [Step 3/6] Generating events...
# ✓ Generated events:
#      count  proportion
# bin
# 0    7,911    0.796116
# 1    2,026    0.203884
#
# [Step 4/6] Computing sample weights...
# 2025-12-01 14:21:43.667 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.compute_sample_weights_time_decay
# 2025-12-01 14:21:43.942 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.train_model_with_cv
# ✓ Computed time-decay weights
#
# [Step 5/6] Training model with cross-validation...
# 2025-12-01 14:21:44.996 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.load_and_prepare_training_data
# 2025-12-01 14:21:45.071 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.create_feature_engineering_pipeline
# ✓ Best CV score: 0.3391
# ✓ Best params: {'clf__max_depth': 9, 'clf__max_features': 0.8168886881742096, 'clf__max_samples': 0.5917173949330818, 'clf__min_weight_fraction_leaf': 0.04118764001091077, 'clf__n_estimators': 120}
#
# [Step 6/6] Analyzing feature importance...
#
# Top 10 Features:
#      feature  importance
#       d1_vol    0.397741
#          vol    0.040409
#       h1_vol    0.028852
#       spread    0.026054
#      atrr_14    0.025496
#  ret_1_lag_2    0.024160
#   bbb_15_1.5    0.023745
# ret_10_lag_3    0.022784
#  ret_1_lag_3    0.020761
#       h4_vol    0.019431
# 3.
#   {'account_name': 'FUNDEDNEXT_STLR2_6K', 'bar_type': 'time', 'bar_size': 'M5', 'price': 'mid_price'}
#   {'bb_period': 15, 'bb_std': 1.5}
#   {'target_lookback': 20, 'profit_target': 0.0, 'stop_loss': 1.5, 'max_holding_period': {'days': 1}, 'min_ret': 0, 'vertical_barrier_zero': True, 'strategy': <afml.strategies.signals.BollingerStrategy object at 0x00000234409C7670>}
#   {'pipe_clf': MyPipeline(steps=[('drop_constant', DropConstantFeatures(tol=0.998)),
#                   ('drop_duplicates', DropDuplicateFeatures()),
#                   ('clf',
#                    RandomForestClassifier(class_weight='balanced_subsample',
#                                           n_jobs=3, random_state=42))]), 'param_grid': {'clf__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002343090C790>, 'clf__max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002343090CBB0>, 'clf__max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090C1F0>, 'clf__max_samples': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090C100>, 'clf__min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000002343090CC10>}, 'cv_splits': 5, 'bagging_n_estimators': 0, 'bagging_max_samples': 1, 'bagging_max_features': 1, 'rnd_search_iter': 1, 'n_jobs': -1, 'pct_embargo': 0.01, 'random_state': 42, 'verbose': False}
#
#
# ======================================================================
# PRODUCTION MODEL DEVELOPMENT PIPELINE
# ======================================================================
#
# [Step 1/6] Loading training data...
# ✓ Loaded 147,860 samples from 2022-01-01 to 2023-12-31
#
# [Step 2/6] Computing features...
# 2025-12-01 14:21:45.302 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.generate_events_triple_barrier
# 2025-12-01 14:21:45.389 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.compute_sample_weights_time_decay
# ✓ Generated 59 features
#
# [Step 3/6] Generating events...
# ✓ Generated events:
#      count  proportion
# bin
# 0    7,355    0.740312
# 1    2,580    0.259688
#
# [Step 4/6] Computing sample weights...
# ✓ Computed time-decay weights
#
# [Step 5/6] Training model with cross-validation...
# 2025-12-01 14:21:46.066 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for afml.production.model_development.train_model_with_cv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 20
#      18 all_cv_metrics.setdefault(i, {})
#      19 all_cv_metrics[i]["key"] = [data_cfg, feature_cfg, label_cfg, model_params, sample_weight_cfg]
# ---> 20 best_model, model_features, metrics = develop_production_model(
#      21     symbol, start_date, end_date, data_cfg, feat_params, label_cfg, model_params, sample_weight_cfg
#      22 )
#      23 all_cv_metrics[i]["result"] = best_model, model_features, metrics
#      24 break
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\production\model_development.py:298, in develop_production_model(symbol, train_start, train_end, data_config, feature_config, label_config, model_params, sample_weight_params, reports)
#     296 # Step 5: Model training with CV (cached)
#     297 print("\n[Step 5/6] Training model with cross-validation...")
# --> 298 best_model, cv_results = train_model_with_cv(features, events, sample_weights, **model_params)
#     299 print(f"✓ Best CV score: {cv_results['best_score']:.4f}")
#     300 print(f"✓ Best params: {cv_results['best_params']}")
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\cache\robust_cache_keys.py:366, in create_robust_cacheable.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     363 try:
#     364     if is_hit:
#     365         # For cache hits, just return cached result (no timing needed)
# --> 366         result = cached_func(*args, **kwargs)
#     367     else:
#     368         # For cache misses, time the computation
#     369         result = cached_func(*args, **kwargs)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\memory.py:607, in MemorizedFunc.__call__(self, *args, **kwargs)
#     605 def __call__(self, *args, **kwargs):
#     606     # Return the output, without the metadata
# --> 607     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\memory.py:562, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     556     self.warn(
#     557         f"Computing func {func_name}, argument hash {args_id} "
#     558         f"in location {location}"
#     559     )
#     561 # Returns the output but not the metadata
# --> 562 return self._call(call_id, args, kwargs, shelving)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\memory.py:832, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     830 self._before_call(args, kwargs)
#     831 start_time = time.time()
# --> 832 output = self.func(*args, **kwargs)
#     833 return self._after_call(call_id, args, kwargs, shelving, output, start_time)
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\production\model_development.py:218, in train_model_with_cv(features, events, sample_weights, pipe_clf, param_grid, cv_splits, bagging_n_estimators, bagging_max_samples, bagging_max_features, rnd_search_iter, n_jobs, pct_embargo, random_state, verbose)
#     216 t1 = events.loc[train_idx, "t1"]
#     217 w = sample_weights.loc[train_idx]
# --> 218 best_model, cv_results = clf_hyper_fit(
#     219     X,
#     220     y,
#     221     t1,
#     222     pipe_clf,
#     223     param_grid,
#     224     cv_splits,
#     225     bagging_n_estimators,
#     226     bagging_max_samples,
#     227     bagging_max_features,
#     228     rnd_search_iter,
#     229     n_jobs,
#     230     pct_embargo,
#     231     random_state,
#     232     verbose,
#     233     sample_weight=w,
#     234 )
#     236 return best_model, cv_results
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\cross_validation\hyperfit.py:197, in clf_hyper_fit(features, labels, t1, pipe_clf, param_grid, cv, bagging_n_estimators, bagging_max_samples, bagging_max_features, rnd_search_iter, n_jobs, pct_embargo, random_state, verbose, **fit_params)
#     184 else:
#     185     gs = RandomizedSearchCV(
#     186         estimator=pipe_clf,
#     187         param_distributions=param_grid,
#    (...)
#     194         refit=True,
#     195     )
# --> 197 gs = gs.fit(features, labels, **fit_params)
#     198 cv_results = {
#     199     "best_params": gs.best_params_,
#     200     "best_score": gs.best_score_,
#     201     "cv_results": pd.DataFrame(gs.cv_results_),
#     202     "scoring": scoring,
#     203 }
#     204 gs = gs.best_estimator_
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\model_selection\_search.py:1062, in BaseSearchCV.fit(self, X, y, **params)
#    1060 refit_start_time = time.time()
#    1061 if y is not None:
# -> 1062     self.best_estimator_.fit(X, y, **routed_params.estimator.fit)
#    1063 else:
#    1064     self.best_estimator_.fit(X, **routed_params.estimator.fit)
#
# File c:\users\joen\documents\github\machine-learning-blueprint\afml\cross_validation\hyperfit.py:18, in MyPipeline.fit(self, X, y, sample_weight, **fit_params)
#      16 if sample_weight is not None:
#      17     fit_params[self.steps[-1][0] + "__sample_weight"] = sample_weight
# ---> 18 return super().fit(X, y, **fit_params)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\pipeline.py:662, in Pipeline.fit(self, X, y, **params)
#     656     if self._final_estimator != "passthrough":
#     657         last_step_params = self._get_metadata_for_step(
#     658             step_idx=len(self) - 1,
#     659             step_params=routed_params[self.steps[-1][0]],
#     660             all_params=params,
#     661         )
# --> 662         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     664 return self
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\ensemble\_forest.py:487, in BaseForest.fit(self, X, y, sample_weight)
#     476 trees = [
#     477     self._make_estimator(append=False, random_state=random_state)
#     478     for i in range(n_more_estimators)
#     479 ]
#     481 # Parallel loop: we prefer the threading backend as the Cython code
#     482 # for fitting the trees is internally releasing the Python GIL
#     483 # making threading more efficient than multiprocessing in
#     484 # that case. However, for joblib 0.12+ we respect any
#     485 # parallel_backend contexts set at a higher level,
#     486 # since correctness does not rely on using threads.
# --> 487 trees = Parallel(
#     488     n_jobs=self.n_jobs,
#     489     verbose=self.verbose,
#     490     prefer="threads",
#     491 )(
#     492     delayed(_parallel_build_trees)(
#     493         t,
#     494         self.bootstrap,
#     495         X,
#     496         y,
#     497         sample_weight,
#     498         i,
#     499         len(trees),
#     500         verbose=self.verbose,
#     501         class_weight=self.class_weight,
#     502         n_samples_bootstrap=n_samples_bootstrap,
#     503         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     504     )
#     505     for i, t in enumerate(trees)
#     506 )
#     508 # Collect newly grown trees
#     509 self.estimators_.extend(trees)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\ensemble\_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree._fit(
#     190         X,
#     191         y,
#     192         sample_weight=curr_sample_weight,
#     193         check_input=False,
#     194         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     195     )
#     196 else:
#     197     tree._fit(
#     198         X,
#     199         y,
#    (...)
#     202         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     203     )
#
# File c:\Users\JoeN\miniforge3\envs\mlfinlab_env\lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# from afml.cache import clear_afml_cache
# from afml.cache.cv_cache import clear_cv_cache


# clear_afml_cache(), clear_cv_cache()
# Out:
# 2025-12-01 02:41:06.355 | WARNING  | afml.cache:clear_afml_cache:168 - Clearing AFML cache...
# [Memory(location=C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache\joblib)]: Flushing completely the cache
# 2025-12-01 02:41:06.667 | INFO     | afml.cache.cv_cache:clear_cv_cache:445 - Cleared 257 CV cache files
# (None, 257)

# %% [markdown]
# #### CV of Weighting Methods

# %%
from os import cpu_count

# Reserve 1 CPU if you want to do something else during training, otherwise set to -1
N_JOBS = cpu_count() - 1
N_ESTIMATORS = 100
seed = 7
min_w_leaf = 0.05
max_depth = 4
n_splits = 5
pct_embargo = 0.01
test_size = 0.2

# %%
train_idx = bb_events_tb_time.index.intersection(bb_feat_time.index)
cont = bb_events_tb_time.reindex(train_idx)
X = bb_feat_time.reindex(train_idx)
y = cont["bin"]
t1 = cont["t1"]

train, test = PurgedSplit(t1, test_size).split(X)
X_train, X_test, y_train, y_test = (
        X.iloc[train],
        X.iloc[test],
        y.iloc[train],
        y.iloc[test],
    )

cont_train = get_event_weights(cont.iloc[train], bb_time_bars.close)

cv_gen = PurgedKFold(n_splits, cont_train["t1"], pct_embargo)

# %%
avg_u = cont_train.tW.mean()
print(f"Average Uniqueness in Training Set: {avg_u:.4f}")

weighting_schemes = {
    "unweighted": pd.Series(1., index=cont_train.index),
    "uniqueness": cont_train["tW"],
    "return": cont_train["w"],
    }

decay_factors = [0.0, 0.25, 0.5, 0.75]
time_decay_weights = {}
for time_decay in decay_factors:
    decay_w = get_weights_by_time_decay_optimized(
                triple_barrier_events=cont_train,
                close_index=bb_time_bars.index,
                last_weight=time_decay,
                linear=True,
                av_uniqueness=cont_train["tW"],
            )
    time_decay_weights[f"decay_{time_decay}"] = decay_w
        
weighting_schemes.keys()
# Out:
# Average Uniqueness in Training Set: 0.4350
# dict_keys(['unweighted', 'uniqueness', 'return'])

# %% [markdown]
# ##### Selection of Best Model

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize Random Forest


clf = RandomForestClassifier(
    criterion='entropy',
    n_estimators=N_ESTIMATORS,
    class_weight="balanced_subsample",
    max_samples=avg_u,
    min_weight_fraction_leaf=min_w_leaf,
    max_depth=max_depth,
    random_state=seed,
    n_jobs=N_JOBS,  # Use all available cores
    )

# %% [markdown]
# - Analyze all CV scores for all weighting schemes to find the best scheme

# %%
all_cv_scores_df = pd.DataFrame()
all_cv_scores_d = {}
all_cms = {}
best_score = 0
best_scheme = "unweighted"

if set(y_train.values) == {0, 1}:
    scoring = "f1"  # f1 for meta-labeling
else:
    scoring = "neg_log_loss"  # symmetric towards all cases

for scheme, w in tqdm(weighting_schemes.items()):
    cv_scores, cv_scores_df, cms = analyze_cross_val_scores(
        clf, X_train, y_train, cv_gen, 
        sample_weight_train=w, 
        sample_weight_score=w,
    )
    all_cms[scheme] = cms
    all_cv_scores_d[scheme] = cv_scores
    score = cv_scores[scoring].mean()
    recall = cv_scores_df.loc["recall", "mean"]
    recall_std = cv_scores_df.loc["recall", "std"]

    for idx, row in cv_scores_df.iterrows():
        all_cv_scores_df.loc[idx, scheme] = f"{row['mean']:.4f} ± {row['std']:.4f}"
    
    best_score = max(best_score, score)
    if score == best_score:
        best_scheme = scheme

print(f"{best_scheme.title()} is the best weighting scheme with {scoring} = {best_score:.4f}")
print("\nWeighting Scheme CV:")
all_cv_scores_df
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]2025-11-28 21:00:04.684 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:04.698 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:04.710 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 100%|██████████| 3/3 [00:00<00:00, 81.08it/s]
# Uniqueness is the best weighting scheme with f1 = 0.6565
#
# Weighting Scheme CV:
#                     unweighted        uniqueness            return
# accuracy       0.5359 ± 0.0177   0.5532 ± 0.0299   0.6084 ± 0.0157
# pwa            0.5483 ± 0.0309   0.5718 ± 0.0181   0.6164 ± 0.0139
# neg_log_loss  -0.6910 ± 0.0058  -0.6867 ± 0.0028  -0.6753 ± 0.0092
# precision      0.5936 ± 0.0170   0.6040 ± 0.0139   0.2582 ± 0.3876
# recall         0.6180 ± 0.0404   0.7213 ± 0.0650   0.0033 ± 0.0045
# f1             0.6047 ± 0.0185   0.6565 ± 0.0330   0.0063 ± 0.0088

# %% [markdown]
# - Test if time-decay improves performance of best model

# %%
best_model_decay_cv_scores = pd.DataFrame()

for scheme, decay_factor in tqdm(time_decay_weights.items()):
    best_scheme_o = best_scheme.split("_decay")[0]
    sample_weight = weighting_schemes[best_scheme_o] * decay_factor
    cv_scores, cv_scores_df, cms = analyze_cross_val_scores(
        clf, X_train, y_train, cv_gen, 
        sample_weight_train=sample_weight, 
        sample_weight_score=sample_weight,
    )
    score = cv_scores[scoring].mean()
    best_score = max(best_score, score)
    scheme = f"{best_scheme_o}_{scheme}"
    all_cv_scores_d[scheme] = cv_scores
    all_cms[scheme] = cms
    for idx, row in cv_scores_df.iterrows():
        best_model_decay_cv_scores.loc[idx, scheme] = f"{row['mean']:.4f} ± {row['std']:.4f}"
    if score == best_score:
        best_scheme = scheme
        weighting_schemes[best_scheme] = sample_weight
    all_cv_scores_df[scheme] = best_model_decay_cv_scores[scheme]
best_model_decay_cv_scores[f"{best_scheme_o}_decay_1.0"] = all_cv_scores_df[best_scheme_o]
        
print(f"\n{best_scheme.title()} model achieved the best {scoring} score of {best_score:.4f}")
best_model_decay_cv_scores
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]2025-11-28 21:00:05.129 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:05.151 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:05.168 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:05.187 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 100%|██████████| 4/4 [00:00<00:00, 51.28it/s]
# Uniqueness_Decay_0.0 model achieved the best f1 score of 0.6708
#              uniqueness_decay_0.0 uniqueness_decay_0.25 uniqueness_decay_0.5  \
# accuracy          0.5556 ± 0.0186       0.5542 ± 0.0177      0.5560 ± 0.0213
# pwa               0.5779 ± 0.0152       0.5760 ± 0.0157      0.5755 ± 0.0141
# neg_log_loss     -0.6858 ± 0.0024      -0.6859 ± 0.0024     -0.6860 ± 0.0022
# precision         0.6033 ± 0.0129       0.6043 ± 0.0113      0.6051 ± 0.0119
# recall            0.7577 ± 0.0548       0.7330 ± 0.0431      0.7354 ± 0.0636
# f1                0.6708 ± 0.0235       0.6619 ± 0.0208      0.6626 ± 0.0263
#
#              uniqueness_decay_0.75 uniqueness_decay_1.0
# accuracy           0.5559 ± 0.0257      0.5532 ± 0.0299
# pwa                0.5723 ± 0.0186      0.5718 ± 0.0181
# neg_log_loss      -0.6866 ± 0.0027     -0.6867 ± 0.0028
# precision          0.6052 ± 0.0127      0.6040 ± 0.0139
# recall             0.7303 ± 0.0667      0.7213 ± 0.0650
# f1                 0.6607 ± 0.0304      0.6565 ± 0.0330

# %% [markdown]
# ##### Sequential Bootstrap

# %%
# Random Forest default of max_features is sqrt, which means I don't have to calculate or set it.
base_rf = clone(clf).set_params(
    n_estimators=1,
    bootstrap=False,
    n_jobs=None,
    max_samples=None,
    random_state=None,
    )

seq_rf = SequentiallyBootstrappedBaggingClassifier(
    samples_info_sets=cont_train.t1,
    price_bars_index=bb_time_bars.index,
    estimator=base_rf,
    n_estimators=N_ESTIMATORS, # set low to save time
    max_samples=avg_u, # Set to average uniqueness
    oob_score=True,
    n_jobs=N_JOBS,
    random_state=seed,
    verbose=False,
)
seq_rf
# Out:
# SequentiallyBootstrappedBaggingClassifier(estimator=RandomForestClassifier(bootstrap=False,
#                                                                            class_weight='balanced_subsample',
#                                                                            criterion='entropy',
#                                                                            max_depth=4,
#                                                                            min_weight_fraction_leaf=0.05,
#                                                                            n_estimators=1),
#                                           max_samples=0.4349923326775145,
#                                           n_estimators=100, n_jobs=3,
#                                           oob_score=True,
#                                           price_bars_index=DatetimeIndex(['2022-01-03 00:05:00', '2022-01-03 00:10:00',
#                '...
# 2022-01-04 08:15:00   2022-01-04 09:15:00
# 2022-01-04 10:35:00   2022-01-04 11:55:00
# 2022-01-04 12:25:00   2022-01-04 16:15:00
# 2022-01-04 16:20:00   2022-01-05 02:00:00
#                               ...
# 2023-06-02 15:30:00   2023-06-02 15:50:00
# 2023-06-02 16:35:00   2023-06-05 00:05:00
# 2023-06-02 18:50:00   2023-06-05 00:05:00
# 2023-06-05 02:05:00   2023-06-06 02:05:00
# 2023-06-05 14:35:00   2023-06-05 16:05:00
# Name: t1, Length: 2967, dtype: datetime64[ns],
#                                           verbose=False)

# %%
w = weighting_schemes[best_scheme]
rf = clone(clf).set_params(oob_score=True)

print(f"Training: Standard RF (max_samples={avg_u:.3f}) - Unweighted...")
rf = train_rf(rf, X_train, y_train, w)

print(f"Training: Sequential Bootstrap RF (max_samples={avg_u:.3f}) - {best_scheme}...")
seq_rf = train_rf(seq_rf, X_train, y_train, w)

ensembles = {
    "standard_rf": rf,
    "sequential_rf": seq_rf,  # max_samples=avg_u
}

scoring_methods = {
            "f1": f1_score,
            "precision": precision_score,
            "recall": recall_score,
            "neg_log_loss": log_loss,
            "pwa": probability_weighted_accuracy,
            "accuracy": accuracy_score,
        }

all_scores_oos = pd.DataFrame()

for name, classifier in ensembles.items():
    prob = classifier.predict_proba(X_test)[:, 1]
    pred = (prob > 0.5).astype("int8")
    oob_metrics = compute_custom_oob_metrics(classifier, X_train, y_train, w)
    for method, scoring in scoring_methods.items():
        y_pred = prob if scoring in (probability_weighted_accuracy, log_loss) else pred
        score = scoring(y_test, y_pred)
        if method == "neg_log_loss":
            score *= -1
        all_scores_oos.loc[method, name] = score
        all_scores_oos.loc[f"{method}_oob_gap", name] = abs(score - oob_metrics[method])

print(f"\nBest weighting scheme: {best_scheme}")
bb_all_scores_oos = all_scores_oos.copy()
bb_all_scores_oos_time = bb_all_scores_oos.copy()

winsound.Beep(1000, 1000) # Alert

all_scores_oos.round(4)
# Out:
# 2025-11-28 21:00:06.216 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for train_rf
# 2025-11-28 21:00:06.318 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for train_rf
# Training: Standard RF (max_samples=0.435) - Unweighted...
# Training: Sequential Bootstrap RF (max_samples=0.435) - uniqueness_decay_0.0...
#
# Best weighting scheme: uniqueness_decay_0.0
#                       standard_rf  sequential_rf
# f1                         0.6985         0.6869
# f1_oob_gap                 0.1704         0.1618
# precision                  0.5819         0.5899
# precision_oob_gap          0.0530         0.0666
# recall                     0.8735         0.8220
# recall_oob_gap             0.3119         0.2680
# neg_log_loss              -0.6834        -0.6865
# neg_log_loss_oob_gap       0.0026         0.0005
# pwa                        0.5846         0.5700
# pwa_oob_gap                0.0049         0.0032
# accuracy                   0.5655         0.5682
# accuracy_oob_gap           0.0038         0.0141

# %% [markdown]
# ### Tick-Bars

# %%
bb_feat_tick, bb_events_tb_tick = prepare_training_data(
    df=bb_tick_bars, 
    strategy=bb_strategy, 
    feature_engine=create_bollinger_features, 
    feature_params=dict(bb_period=bb_period, bb_std=bb_std), 
    vol_lookback=bb_lookback, 
    vol_multiplier=bb_vol_multiplier, 
    time_horizon=bb_time_horizon, 
    pt_barrier=bb_pt_barrier, 
    sl_barrier=bb_sl_barrier, 
    vertical_barrier_zero=True,
)
# Out:
# 2025-11-28 21:00:15.415 | DEBUG    | afml.cache.robust_cache_keys:wrapper:336 - Cache HIT for __main__.prepare_training_data

# %% [markdown]
# #### CV of Weighting Methods

# %%
from os import cpu_count

# Reserve 1 CPU if you want to do something else during training, otherwise set to -1
N_JOBS = cpu_count() - 1
N_ESTIMATORS = 100
seed = 7
min_w_leaf = 0.05
max_depth = 4
n_splits = 5
pct_embargo = 0.01
test_size = 0.2

# %%
train_idx = bb_events_tb_tick.index.intersection(bb_feat_tick.index)
cont = bb_events_tb_tick.reindex(train_idx)
X = bb_feat_tick.reindex(train_idx)
y = cont["bin"]
t1 = cont["t1"]

train, test = PurgedSplit(t1, test_size).split(X)
X_train, X_test, y_train, y_test = (
        X.iloc[train],
        X.iloc[test],
        y.iloc[train],
        y.iloc[test],
    )
cont_train = get_event_weights(cont.iloc[train], bb_tick_bars.close)

cv_gen = PurgedKFold(n_splits, cont_train["t1"], pct_embargo)

# %%
avg_u = cont_train.tW.mean()
print(f"Average Uniqueness in Training Set: {avg_u:.4f}")

weighting_schemes = {
    "unweighted": pd.Series(1., index=cont_train.index),
    "uniqueness": cont_train["tW"],
    "return": cont_train["w"],
    }

decay_factors = [0.0, 0.25, 0.5, 0.75]
time_decay_weights = {}
for time_decay in decay_factors:
    decay_w = get_weights_by_time_decay_optimized(
                triple_barrier_events=cont_train,
                close_index=bb_tick_bars.index,
                last_weight=time_decay,
                linear=True,
                av_uniqueness=cont_train["tW"],
            )
    time_decay_weights[f"decay_{time_decay}"] = decay_w
        
weighting_schemes.keys()
# Out:
# Average Uniqueness in Training Set: 0.3786
# dict_keys(['unweighted', 'uniqueness', 'return'])

# %% [markdown]
# ##### Selection of Best Model

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize Random Forest


clf = RandomForestClassifier(
    criterion='entropy',
    n_estimators=N_ESTIMATORS,
    class_weight="balanced_subsample",
    max_samples=avg_u,
    min_weight_fraction_leaf=min_w_leaf,
    max_depth=max_depth,
    random_state=seed,
    n_jobs=N_JOBS,  # Use all available cores
    )

# %% [markdown]
# - Analyze all CV scores for all weighting schemes to find the best scheme

# %%
all_cv_scores_df = pd.DataFrame()
all_cv_scores_d = {}
all_cms = {}
best_score = 0
best_scheme = "unweighted"

if set(y_train.values) == {0, 1}:
    scoring = "f1"  # f1 for meta-labeling
else:
    scoring = "neg_log_loss"  # symmetric towards all cases

for scheme, w in tqdm(weighting_schemes.items()):
    cv_scores, cv_scores_df, cms = analyze_cross_val_scores(
        clf, X_train, y_train, cv_gen, 
        sample_weight_train=w, 
        sample_weight_score=w,
    )
    all_cms[scheme] = cms
    all_cv_scores_d[scheme] = cv_scores
    score = cv_scores[scoring].mean()
    recall = cv_scores_df.loc["recall", "mean"]
    recall_std = cv_scores_df.loc["recall", "std"]

    for idx, row in cv_scores_df.iterrows():
        all_cv_scores_df.loc[idx, scheme] = f"{row['mean']:.4f} ± {row['std']:.4f}"
    
    best_score = max(best_score, score)
    if score == best_score:
        best_scheme = scheme

print(f"{best_scheme.title()} is the best weighting scheme with {scoring} = {best_score:.4f}")
print("\nWeighting Scheme CV:")
all_cv_scores_df
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]2025-11-28 21:00:19.283 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:19.299 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:19.314 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 100%|██████████| 3/3 [00:00<00:00, 69.75it/s]
# Uniqueness is the best weighting scheme with f1 = 0.6619
#
# Weighting Scheme CV:
#                     unweighted        uniqueness            return
# accuracy       0.5330 ± 0.0186   0.5601 ± 0.0334   0.5838 ± 0.0094
# pwa            0.5490 ± 0.0304   0.5904 ± 0.0339   0.5868 ± 0.0098
# neg_log_loss  -0.6899 ± 0.0033  -0.6851 ± 0.0039  -0.6957 ± 0.0072
# precision      0.6269 ± 0.0209   0.6320 ± 0.0181   0.0000 ± 0.0000
# recall         0.5825 ± 0.0550   0.6975 ± 0.0736   0.0000 ± 0.0000
# f1             0.6029 ± 0.0345   0.6619 ± 0.0419   0.0000 ± 0.0000

# %% [markdown]
# - Test if time-decay improves performance of best model

# %%
best_model_decay_cv_scores = pd.DataFrame()

for scheme, decay_factor in tqdm(time_decay_weights.items()):
    best_scheme_o = best_scheme.split("_decay")[0]
    sample_weight = weighting_schemes[best_scheme_o] * decay_factor
    cv_scores, cv_scores_df, cms = analyze_cross_val_scores(
        clf, X_train, y_train, cv_gen, 
        sample_weight_train=sample_weight, 
        sample_weight_score=sample_weight,
    )
    score = cv_scores[scoring].mean()
    best_score = max(best_score, score) if best_score is not None else score
    scheme = f"{best_scheme_o}_{scheme}"
    all_cv_scores_d[scheme] = cv_scores
    all_cms[scheme] = cms
    for idx, row in cv_scores_df.iterrows():
        best_model_decay_cv_scores.loc[idx, scheme] = f"{row['mean']:.4f} ± {row['std']:.4f}"
    if score == best_score:
        best_scheme = scheme
        weighting_schemes[best_scheme] = sample_weight
    all_cv_scores_df[scheme] = best_model_decay_cv_scores[scheme]
best_model_decay_cv_scores[f"{best_scheme_o}_decay_1.0"] = all_cv_scores_df[best_scheme_o]
        
print(f"\n{best_scheme.title()} model achieved the best {scoring} score of {best_score:.4f}")
best_model_decay_cv_scores
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]2025-11-28 21:00:19.759 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:19.779 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:19.794 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 2025-11-28 21:00:19.812 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for analyze_cross_val_scores
# 100%|██████████| 4/4 [00:00<00:00, 57.97it/s]
# Uniqueness_Decay_0.0 model achieved the best f1 score of 0.6841
#              uniqueness_decay_0.0 uniqueness_decay_0.25 uniqueness_decay_0.5  \
# accuracy          0.5680 ± 0.0163       0.5535 ± 0.0273      0.5641 ± 0.0315
# pwa               0.6011 ± 0.0079       0.6010 ± 0.0222      0.5954 ± 0.0302
# neg_log_loss     -0.6838 ± 0.0012      -0.6841 ± 0.0029     -0.6848 ± 0.0035
# precision         0.6312 ± 0.0154       0.6201 ± 0.0137      0.6293 ± 0.0159
# recall            0.7481 ± 0.0417       0.7285 ± 0.0631      0.7250 ± 0.0644
# f1                0.6841 ± 0.0203       0.6690 ± 0.0329      0.6730 ± 0.0366
#
#              uniqueness_decay_0.75 uniqueness_decay_1.0
# accuracy           0.5579 ± 0.0294      0.5601 ± 0.0334
# pwa                0.5912 ± 0.0323      0.5904 ± 0.0339
# neg_log_loss      -0.6853 ± 0.0036     -0.6851 ± 0.0039
# precision          0.6286 ± 0.0141      0.6320 ± 0.0181
# recall             0.7047 ± 0.0689      0.6975 ± 0.0736
# f1                 0.6633 ± 0.0372      0.6619 ± 0.0419

# %% [markdown]
# ##### Sequential Bootstrap

# %%
w = weighting_schemes[best_scheme]
rf = clone(clf).set_params(oob_score=True)

print(f"Training: Standard RF (max_samples={avg_u:.3f}) - Unweighted...")
rf = train_rf(rf, X_train, y_train, w)

print(f"Training: Sequential Bootstrap RF (max_samples={avg_u:.3f}) - {best_scheme}...")
seq_rf = train_rf(seq_rf, X_train, y_train, w)

ensembles = {
    "standard_rf": rf,
    "sequential_rf": seq_rf,  # max_samples=avg_u
}
scoring_methods = {
            "f1": f1_score,
            "precision": precision_score,
            "recall": recall_score,
            "neg_log_loss": log_loss,
            "pwa": probability_weighted_accuracy,
            "accuracy": accuracy_score,
        }

all_scores_oos = pd.DataFrame()

for name, classifier in ensembles.items():
    prob = classifier.predict_proba(X_test)[:, 1]
    pred = (prob > 0.5).astype("int8")
    oob_metrics = compute_custom_oob_metrics(classifier, X_train, y_train, w)
    for method, scoring in scoring_methods.items():
        y_pred = prob if scoring in (probability_weighted_accuracy, log_loss) else pred
        score = scoring(y_test, y_pred)
        if method == "neg_log_loss":
            score *= -1
        all_scores_oos.loc[method, name] = score
        all_scores_oos.loc[f"{method}_oob_gap", name] = abs(score - oob_metrics[method])

print(f"\nBest weighting scheme: {best_scheme}")
bb_all_scores_oos = all_scores_oos.copy()
bb_all_scores_oos_tick = bb_all_scores_oos.copy()

winsound.Beep(1000, 1000) # Alert

all_scores_oos.round(4)
# Out:
# 2025-11-28 21:00:20.709 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for train_rf
# 2025-11-28 21:00:20.779 | INFO     | afml.cache.cv_cache:wrapper:251 - CV cache hit for train_rf
# Training: Standard RF (max_samples=0.379) - Unweighted...
# Training: Sequential Bootstrap RF (max_samples=0.379) - uniqueness_decay_0.0...
#
# Best weighting scheme: uniqueness_decay_0.0
#                       standard_rf  sequential_rf
# f1                         0.6327         0.6442
# f1_oob_gap                 0.0899         0.1083
# precision                  0.5595         0.5653
# precision_oob_gap          0.0235         0.0365
# recall                     0.7278         0.7489
# recall_oob_gap             0.1685         0.1897
# neg_log_loss              -0.6917        -0.6906
# neg_log_loss_oob_gap       0.0060         0.0037
# pwa                        0.5338         0.5448
# pwa_oob_gap                0.0593         0.0485
# accuracy                   0.5249         0.5351
# accuracy_oob_gap           0.0344         0.0241

# %% [markdown]
# ### Cache Analysis

# %%
# from afml.cache import clear_afml_cache

# clear_afml_cache()

# %%
from afml.cache import get_cache_size_info, print_cache_health

print_cache_health()
# Out:
# 2025-12-01 14:08:52.198 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.203 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_load_and_prepare_training_data', 'load_and_prepare_training_data']
# 2025-12-01 14:08:52.286 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 662 bytes
# 2025-12-01 14:08:52.288 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 263 bytes
# 2025-12-01 14:08:52.290 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 4437512 bytes
# 2025-12-01 14:08:52.305 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.load_and_prepare_training_data: 4.23 MB (3 files)
# 2025-12-01 14:08:52.306 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.308 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_create_feature_engineering_pipeline', 'create_feature_engineering_pipeline']
# 2025-12-01 14:08:52.376 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 278 bytes
# 2025-12-01 14:08:52.378 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1674 bytes
# 2025-12-01 14:08:52.380 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 31733899 bytes
# 2025-12-01 14:08:52.408 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.create_feature_engineering_pipeline: 30.27 MB (3 files)
# 2025-12-01 14:08:52.409 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.411 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 2025-12-01 14:08:52.485 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 2700 bytes
# 2025-12-01 14:08:52.487 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1582 bytes
# 2025-12-01 14:08:52.490 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 31733899 bytes
# 2025-12-01 14:08:52.494 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (3 files)
# 2025-12-01 14:08:52.495 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.497 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_generate_events_triple_barrier', 'generate_events_triple_barrier']
# 2025-12-01 14:08:52.663 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 1131 bytes
# 2025-12-01 14:08:52.666 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.670 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339686 bytes
# 2025-12-01 14:08:52.673 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1790 bytes
# 2025-12-01 14:08:52.674 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339454 bytes
# 2025-12-01 14:08:52.677 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.679 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.686 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1790 bytes
# 2025-12-01 14:08:52.688 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339622 bytes
# 2025-12-01 14:08:52.692 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1790 bytes
# 2025-12-01 14:08:52.696 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.704 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1792 bytes
# 2025-12-01 14:08:52.710 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339558 bytes
# 2025-12-01 14:08:52.718 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.720 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.723 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.725 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.728 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.730 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.735 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1789 bytes
# 2025-12-01 14:08:52.738 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339738 bytes
# 2025-12-01 14:08:52.742 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1791 bytes
# 2025-12-01 14:08:52.746 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 339686 bytes
# 2025-12-01 14:08:52.779 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.generate_events_triple_barrier: 3.58 MB (23 files)
# 2025-12-01 14:08:52.784 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:52.786 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_compute_sample_weights_time_decay', 'compute_sample_weights_time_decay']
# 2025-12-01 14:08:52.806 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 854 bytes
# 2025-12-01 14:08:52.810 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.815 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:52.825 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.837 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.844 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.851 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.855 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.857 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:52.861 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.864 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.867 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.872 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:52.876 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.881 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.886 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.890 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:52.893 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.896 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.901 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.904 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:52.912 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.914 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.919 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.923 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:52.926 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.931 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.936 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.938 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.942 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:52.948 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:52.958 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.964 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.969 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.971 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:52.975 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:52.980 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:52.985 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:52.991 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.002 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.008 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.011 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.019 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.023 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.026 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.036 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.039 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:53.042 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.045 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.051 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.056 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:53.062 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.072 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.078 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.081 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.091 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.094 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.097 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.102 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.106 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.108 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:53.111 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.114 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:53.121 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.132 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.140 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.143 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 318953 bytes
# 2025-12-01 14:08:53.147 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.151 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.156 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.159 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.162 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.169 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.172 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.177 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.189 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.194 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.200 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.205 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.234 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.236 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.260 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1546 bytes
# 2025-12-01 14:08:53.265 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319041 bytes
# 2025-12-01 14:08:53.271 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.273 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.280 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.288 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.291 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.294 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319105 bytes
# 2025-12-01 14:08:53.301 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1548 bytes
# 2025-12-01 14:08:53.312 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.321 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.336 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.341 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1546 bytes
# 2025-12-01 14:08:53.343 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.347 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.351 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319169 bytes
# 2025-12-01 14:08:53.356 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.359 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.363 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1549 bytes
# 2025-12-01 14:08:53.374 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.378 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 1547 bytes
# 2025-12-01 14:08:53.380 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 319249 bytes
# 2025-12-01 14:08:53.469 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.compute_sample_weights_time_decay: 15.60 MB (103 files)
# 2025-12-01 14:08:53.471 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:444 - Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 2025-12-01 14:08:53.474 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:459 - Searching for patterns: ['afml_production_model_development_train_model_with_cv', 'train_model_with_cv']
# 2025-12-01 14:08:53.758 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: func_code.py - 1384 bytes
# 2025-12-01 14:08:53.764 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.777 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 393657 bytes
# 2025-12-01 14:08:53.787 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.803 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 393657 bytes
# 2025-12-01 14:08:53.806 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.808 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 392697 bytes
# 2025-12-01 14:08:53.813 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8101 bytes
# 2025-12-01 14:08:53.818 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 397017 bytes
# 2025-12-01 14:08:53.823 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.825 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 395737 bytes
# 2025-12-01 14:08:53.829 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.837 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 397337 bytes
# 2025-12-01 14:08:53.847 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8101 bytes
# 2025-12-01 14:08:53.852 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 392537 bytes
# 2025-12-01 14:08:53.856 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8100 bytes
# 2025-12-01 14:08:53.858 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 395097 bytes
# 2025-12-01 14:08:53.867 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: metadata.json - 8099 bytes
# 2025-12-01 14:08:53.871 | DEBUG    | afml.cache.cache_monitoring:_get_function_cache_size:478 - Found matching cache file: output.pkl - 398297 bytes
# 2025-12-01 14:08:53.906 | INFO     | afml.cache.cache_monitoring:_get_function_cache_size:487 - Cache size for afml.production.model_development.train_model_with_cv: 3.46 MB (19 files)
# ======================================================================
# CACHE HEALTH REPORT
# ======================================================================
#
# Overall Statistics:
#   Total Functions:     6
#   Total Calls:         250
#   Overall Hit Rate:    80.4%
#   Total Cache Size:    87.41 MB
#
# Top Performers (by hit rate):
#   1. load_and_prepare_training_data: 100.0% (50 calls)
#   2. create_feature_engineering_pipeline: 100.0% (50 calls)
#   3. create_bollinger_features: 100.0% (1 calls)
#   4. generate_events_triple_barrier: 100.0% (50 calls)
#   5. compute_sample_weights_time_decay: 100.0% (50 calls)
#
# Worst Performers (by hit rate):
#   1. create_feature_engineering_pipeline: 100.0% (50 calls)
#   2. create_bollinger_features: 100.0% (1 calls)
#   3. generate_events_triple_barrier: 100.0% (50 calls)
#   4. compute_sample_weights_time_decay: 100.0% (50 calls)
#   5. train_model_with_cv: 0.0% (49 calls)
#
# Recommendations:
#   1. Functions with low hit rate: train_model_with_cv. Review cache key generation for these functions.
#
# ======================================================================

# %%
pprint(get_cache_size_info(), sort_dicts=False)
# Out:
# {'base': {'size_bytes': 695752560, 'size_mb': 663.52, 'file_count': 597},
#  'joblib': {'size_bytes': 344528483, 'size_mb': 328.57, 'file_count': 68},
#  'numba': {'size_bytes': 6217168, 'size_mb': 5.93, 'file_count': 164},
#  'backtest': {'size_bytes': 0, 'size_mb': 0.0, 'file_count': 0}}

# %%
# Detailed analysis of cache patterns
from afml.cache.cache_monitoring import analyze_cache_patterns

analyze_cache_patterns()
# Out:
# 19:59:50 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:50 | DEBUG    | Searching for patterns: ['__main___load_data', 'load_data']
# 19:59:50 | DEBUG    | Found matching cache file: func_code.py - 662 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:50 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:50 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: func_code.py - 537 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | INFO     | Cache size for __main__.load_data: 298.30 MB (58 files)
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1581 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 31733899 bytes
# 19:59:51 | INFO     | Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (2 files)
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['afml_cross_validation_cross_validation_analyze_cross_val_scores', 'analyze_cross_val_scores']
# 19:59:51 | DEBUG    | No cache files found for afml.cross_validation.cross_validation.analyze_cross_val_scores
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['__main___train_rf', 'train_rf']
# 19:59:51 | DEBUG    | No cache files found for __main__.train_rf
# {'high_miss_rate_functions': [{'function': '__main__.load_data',
#    'hit_rate': 0.16666666666666666,
#    'calls': 24},
#   {'function': 'afml.cross_validation.cross_validation.analyze_cross_val_scores',
#    'hit_rate': 0.21875,
#    'calls': 32},
#   {'function': '__main__.train_rf',
#    'hit_rate': 0.2222222222222222,
#    'calls': 18}],
#  'unused_caches': [],
#  'large_caches': [{'function': '__main__.load_data',
#    'size_mb': 298.2985153198242,
#    'hit_rate': 0.16666666666666666}],
#  'frequently_accessed': [],
#  'optimization_candidates': []}

# %%
from afml.cache import diagnose_cache_issues

# Run diagnostics
diagnose_cache_issues()
# Out:
# ================================================================================
# CACHE DIAGNOSTICS REPORT
# ================================================================================
#
# 1. BASIC STATS:
#    Tracked functions: 4
#    Total calls: 82
#    Overall hit rate: 25.6%
#
# 2. CACHE EFFICIENCY:
# 19:59:51 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:51 | DEBUG    | Searching for patterns: ['__main___load_data', 'load_data']
# 19:59:51 | DEBUG    | Found matching cache file: func_code.py - 662 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:51 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:51 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: func_code.py - 537 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | INFO     | Cache size for __main__.load_data: 298.30 MB (58 files)
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1581 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 31733899 bytes
# 19:59:52 | INFO     | Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (2 files)
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['afml_cross_validation_cross_validation_analyze_cross_val_scores', 'analyze_cross_val_scores']
# 19:59:52 | DEBUG    | No cache files found for afml.cross_validation.cross_validation.analyze_cross_val_scores
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['__main___train_rf', 'train_rf']
# 19:59:52 | DEBUG    | No cache files found for __main__.train_rf
#    Functions with issues:
#    - 3 functions with <50% hit rate
#
# 3. CACHE SIZES:
#    base: 663.52 MB (597 files)
#    joblib: 328.57 MB (68 files)
#    numba: 5.93 MB (164 files)
#    backtest: 0.00 MB (0 files)
#
# 4. MONITOR STATUS:
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['__main___load_data', 'load_data']
# 19:59:52 | DEBUG    | Found matching cache file: func_code.py - 662 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 17560608 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1017 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 22166416 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 11089328 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 29266560 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1016 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1014 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 3634576 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1166 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 4437488 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1165 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 6056448 bytes
# 19:59:52 | DEBUG    | Found matching cache file: func_code.py - 537 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1015 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 9083888 bytes
# 19:59:52 | INFO     | Cache size for __main__.load_data: 298.30 MB (58 files)
# 19:59:52 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:52 | DEBUG    | Searching for patterns: ['afml_strategies_bollinger_features_create_bollinger_features', 'create_bollinger_features']
# 19:59:52 | DEBUG    | Found matching cache file: metadata.json - 1581 bytes
# 19:59:52 | DEBUG    | Found matching cache file: output.pkl - 31733899 bytes
# 19:59:53 | INFO     | Cache size for afml.strategies.bollinger_features.create_bollinger_features: 30.27 MB (2 files)
# 19:59:53 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:53 | DEBUG    | Searching for patterns: ['afml_cross_validation_cross_validation_analyze_cross_val_scores', 'analyze_cross_val_scores']
# 19:59:53 | DEBUG    | No cache files found for afml.cross_validation.cross_validation.analyze_cross_val_scores
# 19:59:53 | DEBUG    | Looking for cache in: C:\Users\JoeN\AppData\Local\afml\afml\Cache\joblib_cache
# 19:59:53 | DEBUG    | Searching for patterns: ['__main___train_rf', 'train_rf']
# 19:59:53 | DEBUG    | No cache files found for __main__.train_rf
#    Monitor tracking: 4 functions
#    Functions with cache files: 2
#    Functions with timing data: 0
#
# ================================================================================
